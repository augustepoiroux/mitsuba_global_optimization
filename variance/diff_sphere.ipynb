# %%
import drjit as dr
import mitsuba as mi

mi.set_variant('cuda_ad_rgb')

# %%
scene = mi.load_file('../scenes/diff_sphere.xml')
params = mi.traverse(scene)

key = "diffsphere.to_world"
# Our latent variables
pos = mi.Float([0.2, 0.2])
dr.enable_grad(pos)

# The wall color now depends on `theta`
params[key] = mi.Transform4f.translate([pos[0], pos[1], 0.0]).scale(0.5)

# Propagate this change to the scene internal state
params.update()

image = mi.render(scene, params, spp=128)
mi.Bitmap(image)
# Out:
# Bitmap[
#   pixel_format = rgb,
#   component_format = float32,
#   size = [16, 16],
#   srgb_gamma = 0,
#   struct = Struct<12>[
#     float32 R; // @0, premultiplied alpha
#     float32 G; // @4, premultiplied alpha
#     float32 B; // @8, premultiplied alpha
#   ],
#   data = [ 3 KiB of image data ]
# ]

# %%
def get_forward_grad(flag):
    scene = mi.load_file('../scenes/diff_sphere.xml')
    params = mi.traverse(scene)

    key = "diffsphere.to_world"
    # Our latent variables
    x, y = mi.Float(0.5), mi.Float(0.5)
    dr.enable_grad(x, y)

    # The wall color now depends on `theta`
    params[key] = mi.Transform4f.translate([x, y, 0.0]).scale(0.5)

    dr.forward(pos, flag | dr.ADFlag.ClearEdges)
    image = mi.render(scene, params, spp=128)

    # Forward-propagate the gradients to the image
    dr.forward_to(image)

    # Visualize the gradient image
    return dr.grad(image)

# %%
grad = get_forward_grad(dr.ADFlag.BackPropGrad)
print(grad.max_(), grad.min_())
mi.Bitmap(grad / (grad.max_() - grad.min_()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-2ff663f28fd6> in <module>
# ----> 1 grad = get_forward_grad(dr.ADFlag.BackPropGrad)
#       2 print(grad.max_(), grad.min_())
#       3 mi.Bitmap(grad / (grad.max_() - grad.min_()))
#
# <ipython-input-10-ab9c43398149> in get_forward_grad(flag)
#      14
#      15     # Forward-propagate the gradients to the image
# ---> 16     dr.forward_to(image)
#      17
#      18     # Visualize the gradient image
#
# ~/mitsuba3/build/python/drjit/router.py in forward_to(flags, *args)
#    4419     _check_grad_enabled('forward_to', ta, args)
#    4420     enqueue(_dr.ADMode.Backward, *args)
# -> 4421     traverse(ta, _dr.ADMode.Forward, flags)
#    4422
#    4423     return grad(args) if len(args) > 1 else grad(*args)
#
# ~/mitsuba3/build/python/drjit/router.py in traverse(dtype, mode, flags)
#    4348         raise Exception('traverse(): expected a differentiable array type!')
#    4349
# -> 4350     dtype.traverse_(mode, flags)
#    4351
#    4352
#
# ~/mitsuba3/build/python/mitsuba/python/util.py in forward(self)
#     388                             'desired!')
#     389         self.set_grad_out(
# --> 390             self.integrator.render_forward(self.scene, self.params, self.sensor,
#     391                                            self.seed[1], self.spp[1]))
#     392
#
# ~/mitsuba3/build/python/mitsuba/python/ad/integrators/common.py in render_forward(self, scene, params, sensor, seed, spp)
#    1055         # Perform an AD traversal of all registered AD variables that
#    1056         # influence 'image' in a differentiable manner
# -> 1057         dr.forward_to(image)
#    1058
#    1059         return dr.grad(image)
#
# ~/mitsuba3/build/python/drjit/router.py in forward_to(flags, *args)
#    4417
#    4418     ta = _dr.leaf_array_t(args)
# -> 4419     _check_grad_enabled('forward_to', ta, args)
#    4420     enqueue(_dr.ADMode.Backward, *args)
#    4421     traverse(ta, _dr.ADMode.Forward, flags)
#
# ~/mitsuba3/build/python/drjit/router.py in _check_grad_enabled(name, t, a)
#    4354     if _dr.is_diff_v(t) and t.IsFloat:
#    4355         if _dr.flag(_dr.JitFlag.VCallRecord) and not grad_enabled(a):
# -> 4356             raise TypeError(
#    4357                 f'{name}(): the argument does not depend on the input '
#    4358                 'variable(s) being differentiated. Raising an exception '
#
# TypeError: forward_to(): the argument does not depend on the input variable(s) being differentiated. Raising an exception since this is usually indicative of a bug (for example, you may have forgotten to call dr.enable_grad(..)). If this is expected behavior, skip the call to forward_to(..) if ek.grad_enabled(..) returns False.

# %%
sq_grad_sum = get_forward_grad(dr.ADFlag.BackPropVar)
print(sq_grad_sum.max_(), sq_grad_sum.min_())
mi.Bitmap(sq_grad_sum / (sq_grad_sum.max_() - sq_grad_sum.min_()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-03f9a4721dd4> in <module>
# ----> 1 sq_grad_sum = get_forward_grad(dr.ADFlag.BackPropVar)
#       2 print(sq_grad_sum.max_(), sq_grad_sum.min_())
#       3 mi.Bitmap(sq_grad_sum / (sq_grad_sum.max_() - sq_grad_sum.min_()))
#
# <ipython-input-13-ead6568579b1> in get_forward_grad(flag)
#      14
#      15     # Forward-propagate the gradients to the image
# ---> 16     dr.forward_to(image)
#      17
#      18     # Visualize the gradient image
#
# ~/mitsuba3/build/python/drjit/router.py in forward_to(flags, *args)
#    4419     _check_grad_enabled('forward_to', ta, args)
#    4420     enqueue(_dr.ADMode.Backward, *args)
# -> 4421     traverse(ta, _dr.ADMode.Forward, flags)
#    4422
#    4423     return grad(args) if len(args) > 1 else grad(*args)
#
# ~/mitsuba3/build/python/drjit/router.py in traverse(dtype, mode, flags)
#    4348         raise Exception('traverse(): expected a differentiable array type!')
#    4349
# -> 4350     dtype.traverse_(mode, flags)
#    4351
#    4352
#
# ~/mitsuba3/build/python/mitsuba/python/util.py in forward(self)
#     388                             'desired!')
#     389         self.set_grad_out(
# --> 390             self.integrator.render_forward(self.scene, self.params, self.sensor,
#     391                                            self.seed[1], self.spp[1]))
#     392
#
# ~/mitsuba3/build/python/mitsuba/python/ad/integrators/common.py in render_forward(self, scene, params, sensor, seed, spp)
#    1055         # Perform an AD traversal of all registered AD variables that
#    1056         # influence 'image' in a differentiable manner
# -> 1057         dr.forward_to(image)
#    1058
#    1059         return dr.grad(image)
#
# ~/mitsuba3/build/python/drjit/router.py in forward_to(flags, *args)
#    4417
#    4418     ta = _dr.leaf_array_t(args)
# -> 4419     _check_grad_enabled('forward_to', ta, args)
#    4420     enqueue(_dr.ADMode.Backward, *args)
#    4421     traverse(ta, _dr.ADMode.Forward, flags)
#
# ~/mitsuba3/build/python/drjit/router.py in _check_grad_enabled(name, t, a)
#    4354     if _dr.is_diff_v(t) and t.IsFloat:
#    4355         if _dr.flag(_dr.JitFlag.VCallRecord) and not grad_enabled(a):
# -> 4356             raise TypeError(
#    4357                 f'{name}(): the argument does not depend on the input '
#    4358                 'variable(s) being differentiated. Raising an exception '
#
# TypeError: forward_to(): the argument does not depend on the input variable(s) being differentiated. Raising an exception since this is usually indicative of a bug (for example, you may have forgotten to call dr.enable_grad(..)). If this is expected behavior, skip the call to forward_to(..) if ek.grad_enabled(..) returns False.

# %%
ones = get_forward_grad(dr.ADFlag.BackPropOnes)
print(ones.max_(), ones.min_())
mi.Bitmap(ones / (ones.max_() - ones.min_()))
# Out:
# [2.9248955249786377] [0.0]
# Bitmap[
#   pixel_format = rgb,
#   component_format = float32,
#   size = [256, 256],
#   srgb_gamma = 0,
#   struct = Struct<12>[
#     float32 R; // @0, premultiplied alpha
#     float32 G; // @4, premultiplied alpha
#     float32 B; // @8, premultiplied alpha
#   ],
#   data = [ 768 KiB of image data ]
# ]

# %%
var = sq_grad_sum - grad * grad / ones
print(var.max_(), var.min_())
mi.Bitmap(var / (var.max_() - var.min_()))
# Out:
# [5.039287316321861e-07] [-4.749757067656901e-07]
# Bitmap[
#   pixel_format = rgb,
#   component_format = float32,
#   size = [256, 256],
#   srgb_gamma = 0,
#   struct = Struct<12>[
#     float32 R; // @0, premultiplied alpha
#     float32 G; // @4, premultiplied alpha
#     float32 B; // @8, premultiplied alpha
#   ],
#   data = [ 768 KiB of image data ]
# ]

# %%
def get_backward_grad(flag):
    scene = mi.load_file('../scenes/diff_sphere.xml')
    params = mi.traverse(scene)

    key = "diffsphere.to_world"
    # Our latent variables
    x, y = mi.Float(0.2), mi.Float(0.2)
    dr.enable_grad(x, y)

    # The wall color now depends on `theta`
    params[key] = mi.Transform4f.translate([x, y, 0.0]).scale(0.5)

    # Propagate this change to the scene internal state
    params.update()

    image = mi.render(scene, params, spp=512)

    # Backward-propagate the gradients
    dr.backward(image, flag | dr.ADFlag.ClearEdges)

    return dr.grad([x, y])

# %%
grad_b = get_backward_grad(dr.ADFlag.BackPropGrad)
print(grad_b)
# Out:
# [[-21.624645233154297], [-16.840621948242188]]

# %%
sq_grad_sum_b = get_backward_grad(dr.ADFlag.BackPropVar)
print(sq_grad_sum_b)
# Out:
# [[-21.624094009399414], [-16.975772857666016]]

# %%
ones_b = get_backward_grad(dr.ADFlag.BackPropOnes)
print(ones_b)
# Out:
# [[-21.624788284301758], [-16.929744720458984]]

# %%
var_b = sq_grad_sum_b - grad_b * grad_b / ones_b
print(var_b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-64d10c465760> in <module>
# ----> 1 var_b = sq_grad_sum_b - grad_b * grad_b / ones_b
#       2 print(var_b)
#
# TypeError: can't multiply sequence by non-int of type 'list'
